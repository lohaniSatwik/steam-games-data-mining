# %% [markdown]
# <a href="https://colab.research.google.com/github/lohaniSatwik/steam-games-data-mining/blob/master/Code/section4d_svm_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Section 4d — Linear SVM
# **IE500 Data Mining | Team 9 – Brewed Clusters**
#
# > **Google Colab notebook.** Run all cells top to bottom.
#
# ### Setup
# - Model: `LinearSVC` — fast linear SVM using the liblinear solver
# - Continuous columns are **already StandardScaled** — no scaler in the pipeline
# - `dual=False` — required when n_samples > n_features (45K rows, 147 features)
# - **Outer CV:** 5-fold stratified (unbiased performance estimate)
# - **Inner CV:** 3-fold `GridSearchCV` over `C`
# - **Metric:** Macro F1 (primary), per-class F1 (secondary)
# - **Imbalance:** `class_weight='balanced'`
# - **Baseline to beat:** Logistic Regression Macro F1 = 0.4355

# %%
import os
if not os.path.exists('steam-games-data-mining'):
    # !git clone https://github.com/lohaniSatwik/steam-games-data-mining.git
else:
    # !git -C steam-games-data-mining pull
DATA_DIR = 'steam-games-data-mining/Datasets'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.svm import LinearSVC
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.metrics import (
    f1_score, classification_report,
    confusion_matrix, ConfusionMatrixDisplay
)
from collections import Counter
from tqdm.notebook import tqdm
import warnings
warnings.filterwarnings('ignore')

RANDOM_STATE = 42
CLASS_ORDER  = ['Good', 'Mixed', 'Bad']
CLASS_COLORS = {'Good': 'steelblue', 'Mixed': 'sandybrown', 'Bad': 'salmon'}

# Logistic Regression baseline — beat this
BASELINE_F1 = 0.4355

print('Libraries loaded.')
# Out:
# Libraries loaded.

# %%
train = pd.read_csv(f'{DATA_DIR}/train_multiclass.csv')
test  = pd.read_csv(f'{DATA_DIR}/test_multiclass.csv')

X_train = train.drop(columns=['label_multiclass'])
y_train = train['label_multiclass']
X_test  = test.drop(columns=['label_multiclass'])
y_test  = test['label_multiclass']

print(f'X_train: {X_train.shape}  |  X_test: {X_test.shape}')
print(f'Features: {X_train.shape[1]}')
print('\nClass distribution (train):')
vc = y_train.value_counts()
for cls in CLASS_ORDER:
    print(f'  {cls:6s}: {vc[cls]:6,d}  ({vc[cls]/len(y_train)*100:.1f}%)')
# Out:
# X_train: (45324, 147)  |  X_test: (11331, 147)
# Features: 147
#
# Class distribution (train):
#   Good  : 28,671  (63.3%)
#   Mixed : 12,834  (28.3%)
#   Bad   :  3,819  (8.4%)

# %% [markdown]
# ## Nested Cross-Validation
#
# - **Outer loop** (5 folds) — unbiased estimate of generalisation performance
# - **Inner loop** (3-fold `GridSearchCV`) — selects best `C` without touching the outer validation fold
# - `LinearSVC` with `dual=False` is significantly faster than `SVC(kernel='linear')` on large datasets
#
# Expected runtime on Colab: **~10–20 minutes**

# %%
outer_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)
inner_cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=RANDOM_STATE)

param_grid = {'C': [0.01, 0.1, 1, 10]}

outer_scores    = []
best_params_log = []

print('Running 5-fold nested CV (inner 3-fold GridSearchCV)...\n')

for fold, (tr_idx, val_idx) in tqdm(
        enumerate(outer_cv.split(X_train, y_train), 1),
        total=5, desc='Outer folds'):

    X_tr, X_val = X_train.iloc[tr_idx], X_train.iloc[val_idx]
    y_tr, y_val = y_train.iloc[tr_idx], y_train.iloc[val_idx]

    base_clf = LinearSVC(
        class_weight='balanced', dual=False,
        random_state=RANDOM_STATE, max_iter=2000
    )
    gs = GridSearchCV(
        base_clf, param_grid,
        cv=inner_cv, scoring='f1_macro',
        n_jobs=-1, refit=True
    )
    gs.fit(X_tr, y_tr)

    y_pred = gs.predict(X_val)
    f1 = f1_score(y_val, y_pred, average='macro')
    outer_scores.append(f1)
    best_params_log.append(gs.best_params_)

    print(f'  Fold {fold} | Macro F1: {f1:.4f} | {gs.best_params_}')

print(f'\nNested CV  →  Macro F1: {np.mean(outer_scores):.4f} ± {np.std(outer_scores):.4f}')
print(f'Baseline (LR)         →  Macro F1: {BASELINE_F1:.4f}')
print(f'Improvement           →  {np.mean(outer_scores) - BASELINE_F1:+.4f}')
# Out:
# Running 5-fold nested CV (inner 3-fold GridSearchCV)...
# Outer folds:   0%|          | 0/5 [00:00<?, ?it/s]
#   Fold 1 | Macro F1: 0.4704 | {'C': 0.01}
#   Fold 2 | Macro F1: 0.4699 | {'C': 0.01}
#   Fold 3 | Macro F1: 0.4622 | {'C': 0.01}
#   Fold 4 | Macro F1: 0.4661 | {'C': 0.01}
#   Fold 5 | Macro F1: 0.4713 | {'C': 0.01}
#
# Nested CV  →  Macro F1: 0.4680 ± 0.0034
# Baseline (LR)         →  Macro F1: 0.4355
# Improvement           →  +0.0325

# %%
fig, ax = plt.subplots(figsize=(8, 4))
folds = list(range(1, 6))
ax.bar(folds, outer_scores, color='steelblue', edgecolor='white', alpha=0.85)
ax.axhline(np.mean(outer_scores), color='crimson', linestyle='--', linewidth=1.5,
           label=f'SVM Mean = {np.mean(outer_scores):.4f}')
ax.axhline(BASELINE_F1, color='grey', linestyle='--', linewidth=1.5,
           label=f'LR Baseline = {BASELINE_F1:.4f}')
ax.axhline(np.mean(outer_scores) + np.std(outer_scores), color='crimson',
           linestyle=':', linewidth=1, alpha=0.6)
ax.axhline(np.mean(outer_scores) - np.std(outer_scores), color='crimson',
           linestyle=':', linewidth=1, alpha=0.6,
           label=f'±1 std = {np.std(outer_scores):.4f}')
ax.set_xlabel('Outer Fold')
ax.set_ylabel('Macro F1')
ax.set_title('Linear SVM — Nested CV Macro F1 per Fold')
ax.set_xticks(folds)
ax.set_ylim(0, 1)
ax.legend()
plt.tight_layout()
plt.show()

# %%
print('Best hyperparameters across outer folds:')
param_counts = Counter([str(p) for p in best_params_log])
for params, count in param_counts.most_common():
    print(f'  {count:2d} fold(s): {params}')
# Out:
# Best hyperparameters across outer folds:
#    5 fold(s): {'C': 0.01}

# %% [markdown]
# ## Final Model
#
# Re-run `GridSearchCV` on the **full training set** to select the best `C`, then evaluate on the held-out test set **once**.

# %%
print('Fitting final model on full training set...\n')

final_gs = GridSearchCV(
    LinearSVC(
        class_weight='balanced', dual=False,
        random_state=RANDOM_STATE, max_iter=2000
    ),
    param_grid,
    cv=inner_cv, scoring='f1_macro',
    n_jobs=-1, refit=True
)
final_gs.fit(X_train, y_train)

print(f'Best params      : {final_gs.best_params_}')
print(f'Best inner CV F1 : {final_gs.best_score_:.4f}')
# Out:
# Fitting final model on full training set...
#
# Best params      : {'C': 0.1}
# Best inner CV F1 : 0.4677

# %% [markdown]
# ## Test Set Evaluation
#
# > Evaluate on `test_multiclass.csv` **once only** — this is the final performance number.

# %%
final_model = final_gs.best_estimator_
y_pred_test = final_model.predict(X_test)

test_macro_f1 = f1_score(y_test, y_pred_test, average='macro')
print(f'Test set Macro F1 : {test_macro_f1:.4f}')
print(f'LR Baseline       : {BASELINE_F1:.4f}')
print(f'Improvement       : {test_macro_f1 - BASELINE_F1:+.4f}\n')
print('Classification Report (Test Set):')
print(classification_report(y_test, y_pred_test, labels=CLASS_ORDER, target_names=CLASS_ORDER))
# Out:
# Test set Macro F1 : 0.4693
# LR Baseline       : 0.4355
# Improvement       : +0.0338
#
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#         Good       0.75      0.79      0.77      7168
#        Mixed       0.45      0.28      0.34      3208
#          Bad       0.23      0.41      0.29       955
#
#     accuracy                           0.62     11331
#    macro avg       0.48      0.49      0.47     11331
# weighted avg       0.62      0.62      0.61     11331

# %%
cm = confusion_matrix(y_test, y_pred_test, labels=CLASS_ORDER)

fig, ax = plt.subplots(figsize=(6, 5))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=CLASS_ORDER)
disp.plot(ax=ax, colorbar=False, cmap='Blues')
ax.set_title('Linear SVM — Confusion Matrix (Test Set)', pad=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Feature Importance
#
# `LinearSVC` (One-vs-Rest) produces one coefficient per feature per class — same interpretation as Logistic Regression.
# Larger absolute value = stronger influence on the SVM decision boundary for that class.

# %%
feature_names = X_train.columns.tolist()
coef = final_model.coef_   # shape: (n_classes, n_features)

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

for i, cls in enumerate(final_model.classes_):
    color = CLASS_COLORS[cls]
    coef_series = pd.Series(coef[i], index=feature_names)
    top_idx = coef_series.abs().nlargest(15).index
    coef_series[top_idx].sort_values().plot(
        kind='barh', ax=axes[i], color=color, alpha=0.85
    )
    axes[i].axvline(0, color='black', linewidth=0.8)
    axes[i].set_title(f'Top 15 Coefficients — {cls}')
    axes[i].set_xlabel('Coefficient')

plt.suptitle('Linear SVM — Feature Importance (OvR Coefficients)', y=1.02, fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Results Summary
#
# | Metric | Value |
# |--------|-------|
# | Nested CV Macro F1 (mean ± std) | **0.4680 ± 0.0034** |
# | Test set Macro F1 | **0.4693** |
# | Best params (nested CV) | C=0.01 (all 5 folds) |
# | Best params (final model) | C=0.1 |
# | vs LR Baseline (0.4355) | **+0.034** |
#
# **Per-class F1 (test set):**
#
# | Class | Precision | Recall | F1 |
# |-------|-----------|--------|----|
# | Good  | 0.75 | 0.79 | **0.77** |
# | Mixed | 0.45 | 0.28 | **0.34** |
# | Bad   | 0.23 | 0.41 | **0.29** |
#
# **Interpretation:**
# - Linear SVM **beats Logistic Regression** by +0.034 Macro F1 — the SVM margin finds a better decision boundary than plain LR
# - Biggest gain on **Good** (+0.07 F1) — the margin maximisation helps separate the dominant class more cleanly
# - **Mixed and Bad** remain difficult — only marginal improvement (+0.01 each), these classes overlap heavily in feature space
# - All 5 CV folds consistently chose **C=0.01** (strong regularisation) — the data benefits from keeping the model simple
# - CV estimate (0.4680) and test score (0.4693) are very close — no overfitting
